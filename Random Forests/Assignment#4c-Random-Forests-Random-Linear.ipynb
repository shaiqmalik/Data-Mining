# %% [markdown]
# # Assignment No 4c
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests.For this part you will be implementing randomized version of **Randomized Linear** weak learner based Random Forest, i.e. you will be randomly selecting a pair of  features from all set of features and than randomly selecting the parameters for a generic equation of line,i.e. $ax+by+c=0$.
#
# ## TODO:
#
# **Complete the child class LinearWeakLearner in file `weaklearner.py` by writing the missing code.**
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/4,1)),2*np.ones((nexamples/4,1)),3*np.ones((nexamples/4,1)),4*np.ones((nexamples/4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples/4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples/4,1)),2*np.ones((ntexamples/4,1)),3*np.ones((ntexamples/4,1)),4*np.ones((ntexamples/4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Linear')

# %%
print X.shape, Y.shape
# Out:
# (2000, 2) (2000, 1)

# %%
#%pdb
rfc.train(X,Y)
# Out:
# creating a tree
# training a tree
# making right child with # of children: 988
# making left child with # of children: 1012
# making right child with # of children: 495
# making left child with # of children: 493
# making right child with # of children: 488
# making left child with # of children: 7
# making right child with # of children:: 488
# making left child with # of children:: 6
# making right child with # of children: 24
# making left child with # of children: 469
# making right child with # of children:: 24
# making right child with # of children: 140
# making left child with # of children: 329
# making right child with # of children: 505
# making left child with # of children: 507
# making right child with # of children: 8
# making left child with # of children: 497
# making right child with # of children: 2
# making left child with # of children: 6
# making right child with # of children: 490
# making left child with # of children: 7
# making right child with # of children: 434
# making left child with # of children: 73
# making right child with # of children: 91
# making left child with # of children: 343
# making right child with # of children: 29
# making left child with # of children: 44
# appending the created tree to the list
# creating a tree
# training a tree
# making right child with # of children: 


# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-rlinear-10trees.svg',format='svg')

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (2000, 1) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        250    0    0    0   250
# 2.0          0  250    0    0   250
# 3.0          1    1  248    0   250
# 4.0          1    1    0  248   250
# All        252  252  248  248  1000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Yt.flatten() ==  np.array(Ypt)) / float(Yt.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
# %pdb
t.plot_points_range(rfc,X,Y,10000)
# Out:
# Automatic pdb calling has been turned ON
# (10000, 2)
# [1.0, 2.0, 3.0, 4.0]
# tools.py:844: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(True)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# #### What Can You conclude

# %%
#Each tree is a weak leraners but several weak learners combined form a strong leraner that give results with higher accuracy
#Is a beter learner than axis aligned because the seperating lines can now tilt and split better

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
print X.shape, Y.shape
# Out:
# (30000, 2) (30000,)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Linear',usebagging=False,ntrees=20)
rfc.train(X,Y[:,np.newaxis])
# Out:
# creating a tree
# training a tree
# making right child with # of children: 24978
# making left child with # of children: 5022
# making right child with # of children: 6730
# making left child with # of children: 18248
# making right child with # of children: 4285
# making left child with # of children: 2445
# making right child with # of children: 3065
# making left child with # of children: 1220
# making right child with # of children: 1790
# making left child with # of children: 655
# making right child with # of children: 7736
# making left child with # of children: 10512
# making right child with # of children: 6701
# making left child with # of children: 1035
# making right child with # of children: 2431
# making left child with # of children: 8081
# making right child with # of children: 1525
# making left child with # of children: 3497
# making right child with # of children:: 1525
# making right child with # of children: 353
# making left child with # of children: 1172
# making right child with # of children: 414
# making left child with # of children: 3083
# making right child with # of children:: 414
# making right child with # of children: 1998
# making left child with # of children: 1085
# appending the created tree to the list
# creating a tree
# training a tree
# making right child with # of children:
# appending the created tree to the list
# creating a tree
# training a tree
# making right child with # of children: 8327
# making left child with # of children: 21673
# making right child with # of children: 6536
# making left child with # of children: 1791
# making right child with # of children: 5371
# making left child with # of children: 1165
# making right child with # of children: 4
# making left child with # of children: 5367
# making right child with # of children: 1002
# making left child with # of children: 163
# making left child with # of children:: 1791
# making right child with # of children:: 1791
# making right child with # of children: 16387
# making left child with # of children: 5286
# making right child with # of children: 6837
# making left child with # of children: 9550
# making right child with # of children: 3505
# making left child with # of children: 3332
# making right child with # of children: 1671
# making left child with # of children: 7879
# making right child with # of children: 1390
# making left child with # of children: 3896
# making right child with # of children: 904
# making left child with # of children: 486
# making right child with # of children: 3480
# making left child with # of children: 416
# appending the created tree to the list
# creating a tree
# training a tree
# making right child with # of children: 13148
# making left child with # of children: 16852
# making right child with # of children: 8155
# making left child with # of children: 4993
# making right child with # of children: 5321
# making left child with # of children: 2834
# making right child with # of children: 1770
# making left child with # of children: 3551
# making right child with # of children: 837
# making left child with # of children: 1997
# making right child with # of children: 1470
# making left child with # of children: 3523
# making right child with # of children: 1278
# making left child with # of children: 192
# making right child with # of children: 383
# making left child with # of children: 3140
# making right child with # of children: 14430
# making left child with # of children: 2422
# making right child with # of children: 3258
# making left child with # of children: 11172
# making right child with # of children: 2268
# making left child with # of children: 990
# making right child with # of children: 7209
# making left child with # of children: 3963
# making right child with # of children: 2279
# making left child with # of children: 143
# making left child with # of children:: 2279
# making right child with # of children:: 143
# appending the created tree to the list

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000,) 30000
# Predicted     0     1      2    All
# Actual
# 0          9732    20    248  10000
# 1           232  9676     92  10000
# 2            17    16   9967  10000
# All        9981  9712  10307  30000

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (30000,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4852    17   131   5000
# 1            97  4854    49   5000
# 2            12    10  4978   5000
# All        4961  4881  5158  15000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y.flatten() ==  np.array(Yp)) / float(Y.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000, 2)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc,res=0.1)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,40))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...
