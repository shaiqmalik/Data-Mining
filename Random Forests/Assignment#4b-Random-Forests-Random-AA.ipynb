# %% [markdown]
# # Assignment No 4b
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests. For this part you will be implemented randomized version of **Random Axis-Aligned** weak learner based Random Forest, i.e. you will be randomly selecting the feature from all set of features and than setting the threshold by randomly selecting a threshold.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## TODO:
#
# **Complete the code in files `randomForest.py`, `tree.py` and `weakLearner.py` by writing the missing code.**
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples/4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples/4,1)),2*np.ones((nexamples/4,1)),3*np.ones((nexamples/4,1)),4*np.ones((nexamples/4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples/4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples/4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples/4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples/4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples/4,1)),2*np.ones((ntexamples/4,1)),3*np.ones((ntexamples/4,1)),4*np.ones((ntexamples/4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random')

# %%
print X.shape, Y.shape
# Out:
# (2000, 2) (2000, 1)

# %%
#%debug
rfc.train(X,Y)
# Out:
# creating a tree
# training a tree
# making right child with # of children: 1005
# making left child with # of children: 995
# making right child with # of children: 500
# making left child with # of children: 505
# making right child with # of children: 458
# making left child with # of children: 42
# making right child with # of children: 7
# making left child with # of children: 451
# making right child with # of children: 40
# making left child with # of children: 2
# making right child with # of children: 11
# making left child with # of children: 494
# making left child with # of children:: 10
# making right child with # of children: 477
# making left child with # of children: 17
# making right child with # of children: 500
# making left child with # of children: 495
# making right child with # of children: 431
# making left child with # of children: 69
# making right child with # of children: 334
# making left child with # of children: 97
# making right child with # of children: 61
# making left child with # of children: 8
# making right child with # of children: 7
# making left child with # of children: 488
# making right child with # of children: 4
# making left child with # of children: 3
# making right child with # of children: 486
# making left child with # of children: 2
# appending the created tree to the list
# creating a tree
# training a tree
# making right child with # of children: 
# appending the created tree to the list
# creating a tree
# training a tree
# making right child with # of children: 987
# making left child with # of children: 1013
# making right child with # of children: 494
# making left child with # of children: 493
# making right child with # of children: 489
# making left child with # of children: 5
# making right child with # of children: 347
# making left child with # of children: 142
# making right child with # of children: 129
# making left child with # of children: 364
# making right child with # of children: 86
# making left child with # of children: 43
# making right child with # of children: 361
# making left child with # of children: 3
# making right child with # of children: 483
# making left child with # of children: 530
# making right child with # of children: 11
# making left child with # of children: 472
# making right child with # of children: 3
# making left child with # of children: 8
# making right child with # of children: 113
# making left child with # of children: 359
# making right child with # of children: 26
# making left child with # of children: 504
# making right child with # of children: 9
# making left child with # of children: 17
# making right child with # of children: 7
# making left child with # of children: 497
# appending the created tree to the list

# %%
len(rfc.trees)
# Out:
# 10

# %%
# Training Confusion Matrix...
#%pdb
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (2000, 1) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        495    0    2    3   500
# 2.0          0  500    0    0   500
# 3.0          0    1  499    0   500
# 4.0          1    2    0  497   500
# All        496  503  501  500  2000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y ==  np.array(Yp)) / float(Y.shape[0])

assert_greater_equal(acc, 0.78)

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-raa-10trees.svg',format='svg')

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
Ypt=np.array(Ypt)
print Ypt.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (1000,) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        249    0    0    1   250
# 2.0          0  250    0    0   250
# 3.0          1    1  248    0   250
# 4.0          1    2    0  247   250
# All        251  253  248  248  1000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Yt.flatten() ==  np.array(Ypt)) / float(Yt.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
t.plot_points_range(rfc,X,Y,10000)
# Out:
# (10000, 2)
# [1.0, 2.0, 3.0, 4.0]
# tools.py:844: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(True)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# #### What Can You conclude

# %%
#Each tree is a weak leraners but several weak learners combined form a strong leraner that give results with higher accuracy

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random',usebagging=False)
rfc.train(X,Y)
# Out:
# appending the created tree to the list
# creating a tree
# training a tree
# making right child with # of children: 25842
# making left child with # of children: 4158
# making right child with # of children: 7700
# making left child with # of children: 18142
# making right child with # of children: 2612
# making left child with # of children: 5088
# making right child with # of children: 2464
# making left child with # of children: 148
# making right child with # of children: 2822
# making left child with # of children: 2266
# making right child with # of children: 12807
# making left child with # of children: 5335
# making right child with # of children: 10064
# making left child with # of children: 2743
# making right child with # of children: 5298
# making left child with # of children: 37
# making right child with # of children: 1922
# making left child with # of children: 2236
# making right child with # of children: 9
# making left child with # of children: 1913
# making right child with # of children: 2
# making left child with # of children: 7
# making right child with # of children: 1520
# making left child with # of children: 393
# making right child with # of children: 359
# making left child with # of children: 1877
# making right child with # of children: 242
# making left child with # of children: 117
# making right child with # of children: 87
# making left child with # of children: 1790
# appending the created tree to the list
# creating a tree
# training a tree
# making right child with # of children: 26036
# making left child with # of children: 3964
# making right child with # of children: 21652
# making left child with # of children: 4384
# making right child with # of children: 14132
# making left child with # of children: 7520
# making right child with # of children: 3354
# making left child with # of children: 10778
# making right child with # of children: 6790
# making left child with # of children: 730
# making right child with # of children: 4268
# making left child with # of children: 116
# making right child with # of children: 3109
# making left child with # of children: 1159
# making right child with # of children: 98
# making left child with # of children: 18
# making right child with # of children: 414
# making left child with # of children: 3550
# making right child with # of children: 251
# making left child with # of children: 163
# making right child with # of children: 7
# making left child with # of children: 244
# making right child with # of children: 131
# making left child with # of children: 32
# making right child with # of children: 429
# making left child with # of children: 3121
# making right child with # of children: 336
# making left child with # of children: 93
# making right child with # of children: 1723
# making left child with # of children: 1398
# appending the created tree to the list

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print Y.shape, len(Yp)
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000,) 30000
# Predicted      0     1     2    All
# Actual
# 0           9937    12    51  10000
# 1           1160  8840     0  10000
# 2           1632     0  8368  10000
# All        12729  8852  8419  30000

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print Y.shape, len(Ypt)
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (30000,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4974     2    24   5000
# 1           593  4406     1   5000
# 2           826     1  4173   5000
# All        6393  4409  4198  15000

# %%
from nose.tools import assert_greater_equal
acc = np.sum(Y.flatten() ==  np.array(Yp)) / float(Y.shape[0]) 

assert_greater_equal(acc, 0.78)

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000, 2)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc)

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=ntrees/2
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...
